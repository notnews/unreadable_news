# %%
import pandas as pd
pd.options.display.max_columns = 50
import sqlite3
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from data_utils import (
    clean_transcripts,
    flesch,
    fog,
    smog,
    terms,
    uniqueterms, 
    ttr, 
    mtld, 
    hdd
)

con = sqlite3.connect("../data/cbs.db")

# %%
df_cbs = (pd.read_sql_query("SELECT * from cbs_stories", con)
          .rename(columns={'publish_date': 'date'})
          .query('date==date')
          .assign(text=lambda df: df.text.str.strip())
          .query('text!=""')
          .assign(
              text=lambda df: df.text.apply(clean_transcripts),
              # Compute readability
              flesch_reading_ease=lambda df: df.text.apply(flesch),
              fog=lambda df: df.text.apply(fog), 
              smog=lambda df: df.text.apply(smog),  
              terms=lambda df: df.text.apply(terms),
              # Compute lexical richness
              uniqueterms=lambda df: df.text.apply(uniqueterms), 
              ttr=lambda df: df.text.apply(ttr),
              mtld=lambda df: df.text.apply(mtld),
              hdd=lambda df: df.text.apply(hdd),
         )
         )
        

df_cbs.head(3)
# Out:
#   source                                                url  date  \
# 0    CBS  https://www.cbsnews.com/news/supreme-court-dec...  None
# 1    CBS  https://www.cbsnews.com/live-updates/supreme-c...  None
# 2    CBS  https://www.cbsnews.com/news/ben-jerrys-west-b...  None
#
#                                                title  \
# 0  "Extremely dangerous path": Supreme Court deci...
# 1  Supreme Court limits EPA's authority to regula...
# 2  Ben & Jerry's objects to sale of its ice cream...
#
#                                              authors  \
# 0  ["Li Cohen", "Li Cohen Is A Social Media Produ...
# 1                      ["Melissa Quinn", "Li Cohen"]
# 2                                                 []
#
#                                                 text  flesch_reading_ease  \
# 0  the supreme court ruled on thursday to limit t...            46.321875
# 1  rich friends in childhood kansas voters to wei...                  NaN
# 2  a new agreement in israel will put ben & jerry...            41.073093
#
#          fog       smog  terms  uniqueterms       ttr        mtld       hdd
# 0  14.068176  16.292708   1536          586  0.394879  112.303583  0.865770
# 1        NaN        NaN     61           51  0.879310  134.560000  0.898048
# 2  15.601566  17.271064    872          367  0.418472   88.264542  0.835029

# %%
(df_cbs
 .drop('text', axis=1)
 .to_csv('../data/cbs_2_textstat.csv.gz', compression="gzip")
)
