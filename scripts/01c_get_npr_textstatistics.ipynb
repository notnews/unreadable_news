# %%
import os
import pandas as pd
import textstat
from utils import uniqueterms, ttr, mtld, hdd

# FP_NPR = '../../readable_news_lf/news_dialogue.zip'
FP_NPR = 'raw_data/news_dialogue.zip'

# %%
df = (pd.read_json(FP_NPR)
      .query('utt==utt')
      .reset_index(drop=True)
      .assign(text=lambda df: [' '.join(li) for li in df.utt])
      .assign(
          # Compute readability for text
          flesch_reading_ease=lambda df: df.text.apply(textstat.flesch_reading_ease),
          flesch_kincaid_grade=lambda df: df.text.apply(textstat.flesch_kincaid_grade),
          fog=lambda df: df.text.apply(textstat.gunning_fog), 
          smog=lambda df: df.text.apply(textstat.smog_index),  
          terms=lambda df: df.text.apply(textstat.lexicon_count),
          # Compute lexical richness for text
          uniqueterms=lambda df: df.text.apply(uniqueterms), 
          ttr=lambda df: df.text.apply(ttr),
          mtld=lambda df: df.text.apply(mtld),
          hdd=lambda df: df.text.apply(hdd),    
      )          
     )
df.head(3)
# Out:
#       id                 program        date  \
# 0  NPR-1            News & Notes  2007-11-28
# 1  NPR-2  Weekend Edition Sunday  2016-10-23
# 2  NPR-3            News & Notes  2007-11-30
#
#                                                  url  \
# 0  https://www.npr.org/templates/story/story.php?...
# 1  https://www.npr.org/2016/10/23/499042298/young...
# 2  https://www.npr.org/templates/story/story.php?...
#
#                                                title  \
# 0                Black Actors Give Bible Star Appeal
# 1  Young, First-Time Voters Share Views On Electi...
# 2                         Snapshots: On Solid Ground
#
#                                              summary  \
# 0  More than 400 black actors, artists and minist...
# 1  NPR's Rachel Martin speaks with young voters w...
# 2  In this week's snapshot, actor and playwright ...
#
#                                                  utt  \
# 0  [Now, moving on, Forest Whitaker as Moses, Tis...
# 1  [You have heard it again and again - this is a...
# 2  [I came close to running out of luck, when I a...
#
#                                              speaker  \
# 0  [FARAI CHIDEYA, host, FARAI CHIDEYA, host, Mr....
# 1  [RACHEL MARTIN, HOST, ASHANTI MARTINEZ, LAUREN...
# 2  [Mr. JEFF OBAFEMI CARR (Actor, Playwright), CH...
#
#                                                 text  flesch_reading_ease  \
# 0  Now, moving on, Forest Whitaker as Moses, Tish...                73.98
# 1  You have heard it again and again - this is an...                75.50
# 2  I came close to running out of luck, when I al...                79.19
#
#    flesch_kincaid_grade   fog  smog  terms  uniqueterms       ttr        mtld  \
# 0                   6.5  7.66   9.5   1417          479  0.327186   58.140244
# 1                   5.9  6.67   9.1   1914          508  0.252988   69.832405
# 2                   6.5  8.91   8.8    696          358  0.507082  110.833060
#
#         hdd
# 0  0.831717
# 1  0.846484
# 2  0.859794

# %%
(df
 .drop(['text', 'utt'], axis=1)
 .to_csv('data/npr_cnn_textstat.csv.gz', index=False, compression="gzip")
)
