# %%
import os
import pandas as pd
from glob import glob
import textstat
from utils import uniqueterms, ttr, mtld, hdd

# FP_CNN = '../../readable_news_lf/cnn_cc/'
FP_MSNBC1 = 'raw_data/msnbc/msnbc--2003--2014.csv.gz'
FP_MSNBC2 = 'raw_data/msnbc/msnbc-2010--2021.csv.gz'

# %%
df1 = (pd.read_csv(FP_MSNBC1)
       .query('Content==Content')
       .reset_index(drop=True)
       .assign(
           # Compute readability for text
           flesch_reading_ease=lambda df: df.Content.apply(textstat.flesch_reading_ease),
           flesch_kincaid_grade=lambda df: df.Content.apply(textstat.flesch_kincaid_grade),
           fog=lambda df: df.Content.apply(textstat.gunning_fog), 
           smog=lambda df: df.Content.apply(textstat.smog_index),  
           terms=lambda df: df.Content.apply(textstat.lexicon_count),
           # Compute lexical richness for text
           uniqueterms=lambda df: df.Content.apply(uniqueterms), 
           ttr=lambda df: df.Content.apply(ttr),
           mtld=lambda df: df.Content.apply(mtld),
           hdd=lambda df: df.Content.apply(hdd),    
       )           
      )
df1.head(3)
# Out:
#                                       cite Source  \
# 0  MSNBC , Hardball for September 24, 2003  MSNBC
# 1       COUNTDOWN: IRAQ for March 31, 2003  MSNBC
# 2              HARDBALL for March 31, 2003  MSNBC
#
#                           Date             Show  \
# 0  Tuesday, September 24, 2002         HARDBALL
# 1       Monday, March 31, 2003  COUNTDOWN: IRAQ
# 2       Monday, March 31, 2003         HARDBALL
#
#                                               Author  Location(s)  Dateline  \
# 0                        Chris MatthewsDavid Shuster          NaN       NaN
# 1  Keith OlbermannCarl RochelleJohn IrvineKerry S...          NaN       NaN
# 2  Chris MatthewsJohn WardenCarl RochelleJohn Irv...          NaN       NaN
#
#                Section                                        Index Terms  \
# 0  News, International  Terrorism ; Iraq ; Politics ; War ; Elections ...
# 1  News, International  Iraq ; War ; United States ; United Nations ; ...
# 2  News, International                       War ; Military ; Iraq ; SHOW
#
#       Record Number  ...                                            Content  \
# 0  0FE8AF52AF84A531  ...  b'CHRIS MATTHEWS, HOST: I`m Chris Matthews. Le...
# 1  0FE5A1D810A218B3  ...  b'KEITH OLBERMANN, HOST: 8 p.m. in the East, 4...
# 2  0FE5A1CEDF3C105E  ...  b'(BEGIN VIDEO CLIP)\n      \n\n      GEORGE W...
#
#    flesch_reading_ease flesch_kincaid_grade    fog  smog  terms  uniqueterms  \
# 0                37.94                 14.1  11.25  11.6   8740         1619
# 1                30.94                 16.8  14.38  13.7   8027         1966
# 2                31.35                 16.6  13.82  13.1  13316         2328
#
#         ttr       mtld       hdd
# 0  0.163304  41.606257  0.817531
# 1  0.221696  66.644927  0.845062
# 2  0.157244  63.714404  0.849839
#
# [3 rows x 22 columns]

# %%
(df1
 .drop(['Content'], axis=1)
 .to_csv('data/msnbc2003_2014_textstat.csv.gz', index=False, compression="gzip")
)

# %%
df2 = (pd.read_csv(FP_MSNBC2)
       .query('text==text')
       .reset_index(drop=True)
       .assign(
           # Compute readability for text
           flesch_reading_ease=lambda df: df.text.apply(textstat.flesch_reading_ease),
           flesch_kincaid_grade=lambda df: df.text.apply(textstat.flesch_kincaid_grade),
           fog=lambda df: df.text.apply(textstat.gunning_fog), 
           smog=lambda df: df.text.apply(textstat.smog_index),  
           terms=lambda df: df.text.apply(textstat.lexicon_count),
           # Compute lexical richness for text
           uniqueterms=lambda df: df.text.apply(uniqueterms), 
           ttr=lambda df: df.text.apply(ttr),
           mtld=lambda df: df.text.apply(mtld),
           hdd=lambda df: df.text.apply(hdd),    
       )           
      )
df2.head(3)
# Out:
#       air_date               show_name  \
# 0  May 28 2010  The Rachel Maddow Show
# 1  Jun 02 2010  The Rachel Maddow Show
# 2  Jun 03 2010  The Rachel Maddow Show
#
#                                       headline  \
# 0  The Rachel Maddow Show, Transcript 05/27/10
# 1  The Rachel Maddow Show, Transcript 06/01/10
# 2  The Rachel Maddow Show, Transcript 06/02/10
#
#                                               guests  \
# 0  Guests: Rep. Charlie Melancon, Linda Tollner, ...
# 1                                Guests: Chris Hayes
# 2  Guests: Sen. Barbara Boxer, David Muth, Larry ...
#
#                                                  url channel.name  \
# 0  https://www.msnbc.com/transcripts/rachel-maddo...        MSNBC
# 1  https://www.msnbc.com/transcripts/rachel-maddo...        MSNBC
# 2  https://www.msnbc.com/transcripts/rachel-maddo...        MSNBC
#
#                                   program.name  uid  duration  year  ...  \
# 0  The Rachel Maddow Show, Transcript 05/27/10  NaN       NaN  2010  ...
# 1  The Rachel Maddow Show, Transcript 06/01/10  NaN       NaN  2010  ...
# 2  The Rachel Maddow Show, Transcript 06/02/10  NaN       NaN  2010  ...
#
#                                                 text  flesch_reading_ease  \
# 0  KEITH OLBERMANN, HOST, COUNTDOWN:  And now, to...                35.55
# 1  RACHEL MADDOW, HOST:  Good evening, Keith.  Th...                11.26
# 2  KEITH OLBERMANN, “COUNTDOWN” HOST:  And now, f...                11.36
#
#   flesch_kincaid_grade    fog  smog  terms  uniqueterms       ttr       mtld  \
# 0                 23.3  25.41  15.0   8089         1541  0.192049  58.395263
# 1                 30.6  32.15  19.0   7826         1759  0.223507  84.383256
# 2                 30.5  31.97  17.7   7820         1600  0.204473  70.737984
#
#         hdd
# 0  0.870620
# 1  0.876087
# 2  0.872863
#
# [3 rows x 28 columns]

# %%
(df2
 .drop(['text'], axis=1)
 .to_csv('data/msnbc2010_2021_textstat.csv.gz', index=False, compression="gzip")
)
